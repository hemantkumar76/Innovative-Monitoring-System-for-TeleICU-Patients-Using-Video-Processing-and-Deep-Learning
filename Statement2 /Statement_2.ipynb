# %% [markdown]
# # 🚀 Statement 2: Train a new deep learning model to identify various activity of the patient when patient is alone.

# %% [markdown]
# Our mission is to train a new deep learning model to identify various activities of a patient when they are alone. This isn't just about recognizing movement; it's about understanding the patient's state and behavior in the absence of healthcare professionals or family members.
#
# This tool could potentially revolutionize patient care, providing valuable insights into patient behavior and activity when they are alone. It could help healthcare professionals better understand their patients' needs and improve their care.
#
# So, let's embark on this exciting journey of creating a tool that could potentially enhance healthcare efficiency and patient care.
#
# >"Innovation distinguishes between a leader and a follower." - Steve Jobs

# %% [markdown]
# # 📍 Pinpointing Our Location: Current Working Directory
#
# In the vast landscape of our file system, it's crucial to know where we are. Let's find out our current working directory using Python's `os` module. It's time to pinpoint our location!

# %% [markdown]
# This Python script is used to print the current working directory. Here's a brief rundown:
#
# - `import os`: This line imports the `os` module, which provides a way of using operating system dependent functionality.
# - `HOME = os.getcwd()`: This line calls the `getcwd` method from the `os` module, which returns a string representing the current working directory. This string is then assigned to the variable `HOME`.
# - `print(HOME)`: This line prints the value of `HOME`, which is the current working directory.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /Users/hemant./Intel_Final/Statement 2.

# %% [markdown]
# # 🚀 Setting Up: Installing and Checking Ultralytics
#
# Before we dive into our object detection journey, let's ensure our setup is ready. We're installing the Ultralytics library and performing some initial checks. Let's get our environment ready for action!

# %% [markdown]
# This Python script is used to install the Ultralytics library and perform initial checks. Here's a brief rundown:
#
# - `!pip install ultralytics==8.0.20`: This line installs a specific version (8.0.20) of the Ultralytics library using pip, Python's package installer.
# - `from IPython import display` and `display.clear_output()`: These lines import the `display` module from IPython and clear the output of the current cell.
# - `import ultralytics` and `ultralytics.checks()`: These lines import the Ultralytics library and call the `checks` function, which performs initial checks to ensure the library is correctly installed and working.

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.11.5 torch-2.3.0 CPU (Apple M1)
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 144.7/460.4 GB disk)

# %% [markdown]
# # 🕵️‍♀️ Ready for Detection: Importing YOLO and Display Tools
#
# We're gearing up for some object detection! We're importing the YOLO model from the Ultralytics library, and the display tools from IPython. We're all set to detect objects and display our results!

# %% [markdown]
# This Python script is setting up for object detection and image display. Here's a brief rundown:
#
# - `from ultralytics import YOLO`: This line imports the `YOLO` class from the `ultralytics` library. `YOLO` is a popular object detection model.
# - `from IPython.display import display, Image`: This line imports the `display` and `Image` functions from the `IPython.display` module. These functions are used to display Python objects in rich formats, including images, in Jupyter notebooks.

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # 🎯 Setting the Stage: Changing Directory and Running YOLO
#
# We're setting the stage for our object detection task. First, we change our working directory to `HOME`. Then, we run our YOLO model on an image of a dog, setting the confidence threshold to 0.25. Let's see what our model detects!

# %% [markdown]
# # 🎯 Setting the Stage: Changing Directory and Running YOLO
#
# We're setting the stage for our object detection task. First, we change our working directory to `HOME`. Then, we run our YOLO model on an image of a dog, setting the confidence threshold to 0.25. Let's see what our model detects!

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# [Errno 2] No such file or directory: '/Users/hemant./Intel_Final/Statement 2.'
# /Users/hemant./Intel_Final/Statement 2.
# Ultralytics YOLOv8.2.46 🚀 Python-3.11.5 torch-2.3.0 CPU (Apple M1)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /Users/hemant./Intel_Final/Statement 2. /dog.jpeg: 640x384 1 person, 1 car, 1 dog, 58.3ms
# Speed: 1.7ms preprocess, 58.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 🖼️ Picture Time: Displaying Our Detection Result
#
# We've run our YOLO model on an image, and now it's time to see the result! We're changing our working directory back to `HOME` and then displaying the image with our model's detections. Let's see what our model has found!

# %% [markdown]
# This Python script is used to change the current working directory and display an image with object detections. Here's a brief rundown:
#
# - `%cd {HOME}`: This line changes the current working directory to the directory stored in the `HOME` variable.
# - `Image(filename='runs/detect/predict/dog.jpeg', height=600)`: This line creates an `Image` object with the specified filename and height, and displays it. The image file is expected to be in the `runs/detect/predict` directory and is named `dog.jpeg`.

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# [Errno 2] No such file or directory: '/Users/hemant./Intel_Final/Statement 2.'
# /Users/hemant./Intel_Final/Statement 2.

# %% [markdown]
# # 🐾 On the Hunt: Running YOLO on an Image
#
# We're on the hunt for objects in our image! We're loading our YOLO model and running it on an image of a dog, setting the confidence threshold to 0.25. Let's see what our model detects!

# %% [markdown]
# This Python script is used to load the YOLO model and run it on an image. Here's a brief rundown:
#
# - `model = YOLO(f'{HOME}/yolov8n.pt')`: This line creates a `YOLO` object with the model file located at `{HOME}/yolov8n.pt`.
# - `results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)`: This line runs the YOLO model on an image of a dog. The image is specified by a URL, and the confidence threshold is set to 0.25.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /Users/hemant./Intel_Final/Statement 2. /dog.jpeg: 640x384 1 person, 1 car, 1 dog, 86.3ms
# Speed: 2.4ms preprocess, 86.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# # 📦 Unpacking the Results: Inspecting Detection Boxes
#
# We've got our detection results, but what's inside? Let's unpack the details of the detected bounding boxes. We're going to inspect the coordinates, confidence scores, and class labels of the boxes. Let's dive in!

# %% [markdown]
# This Python script is used to inspect the bounding boxes in the detection results. Here's a brief rundown:
#
# - `results[0].boxes.xyxy`: This line accesses the coordinates of the bounding box for the first detection in the results. The coordinates are in the format `(x1, y1, x2, y2)`, where `(x1, y1)` is the top-left corner and `(x2, y2)` is the bottom-right corner of the box.
# - `results[0].boxes.conf`: This line accesses the confidence score of the bounding box for the first detection in the results. The confidence score indicates how confident the model is that the detected object is of the predicted class.
# - `results[0].boxes.cls`: This line accesses the class label of the bounding box for the first detection in the results. The class label indicates the type of object detected.

# %%
results[0].boxes.xyxy
results[0].boxes.conf
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.])

# %% [markdown]
# # 🚀 Navigating the File System: Changing Directory

# %%
ls
# Out:
# Statemen_2.ipynb        dog.jpeg                yolov8s.pt
# Statement 2.v1i.yolov8/ runs/
# Test Data/              yolov8n.pt

# %% [markdown]
# # 🚀 Training Time: Running YOLO for Training
#
# We're not just detecting, we're training! We're running our YOLO model in training mode on our dataset. We're setting the number of epochs to 30 and the image size to 224. We're also enabling plots and saving the results. Let's get our model learning!

# %% [markdown]
# This Python script is used to train the YOLO model on a dataset. Here's a brief rundown:
#
# - `!yolo task=detect mode=train model=yolov8s.pt data="/Users/hemant./Intel_Final/Statement 1. /ICU.v1i.yolov8/data.yaml" epochs=30 imgsz=224 plots=True save=True`: This line runs the YOLO model in training mode. The model is specified as `yolov8s.pt`, the dataset is specified by a YAML file, the number of training epochs is set to 30, the image size is set to 224, plots are enabled, and the output is saved.

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/Users/hemant./Intel_Final/Statement 2. /Statement 2.v1i.yolov8/data.yaml" epochs=100 imgsz=224 plots=True save=True
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.11.5 torch-2.3.0 CPU (Apple M1)
# ...

# %% [markdown]
# # 📊 Unveiling the Insights: Displaying the Confusion Matrix
#
# Now comes the moment of truth! We're about to print the confusion matrix - a powerful tool that will reveal the performance of our model in predicting the various classes. It's not just about numbers, it's about understanding where our model excels and where it needs improvement. So, let's dive in and decode the insights hidden in the confusion matrix!

# %%
Image(filename='/Users/hemant./Intel_Final/Statement 2. /runs/detect/train6/confusion_matrix.png', width=600)

# %% [markdown]
# # 🎯 Putting Our Model to the Test: Validation Time!
#
# After all the training and fine-tuning, it's time to see our model in action. We're going to validate our trained model on a separate dataset. This is the moment where we see how well our model generalizes to new, unseen data. So, let's dive in and see the fruits of our labor!

# %%
# !yolo task=detect mode=val model="/Users/hemant./Intel_Final/Statement 2. /runs/detect/train6/weights/best.pt" data="/Users/hemant./Intel_Final/Statement 2. /Statement 2.v1i.yolov8/data.yaml"
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.11.5 torch-2.3.0 CPU (Apple M1)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /Users/hemant./Intel_Final/Statement 2. /Statement 2.v1i.yolov8/va
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all          8          8      0.895          1      0.984      0.524
#            Movement-NO          6          6      0.855          1      0.972      0.467
#           Movement-Yes          2          2      0.935          1      0.995      0.581
# Speed: 0.3ms preprocess, 38.4ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# # 🖼️ Gallery Walk: Displaying Multiple Images
#
# We're taking a stroll through our image gallery! We're using Python's `glob` module to find all the `.jpg` images in our directory, and then displaying the first three. Let's see what images we have!

# %% [markdown]
# This Python script is used to display multiple images. Here's a brief rundown:
#
# - `import glob`: This line imports the `glob` module, which provides a function for making file lists from directory wildcard searches.
# - `from IPython.display import Image, display`: This line imports the `Image` and `display` functions from the `IPython.display` module. These functions are used to display images in Jupyter notebooks.
# - `for image_path in glob.glob('runs/detect/predict2/*.jpg')[:3]: display(Image(filename=image_path, width=600))`: This line loops over the first three `.jpg` images in the `runs/detect/predict2` directory and displays each one with a width of 600 pixels.

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/predict2/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))

# %% [markdown]
# # 🎥 Lights, Camera, Action: Running Predictions on Our Video
#
# With our model trained and ready, it's showtime! We're deploying our YOLO model to detect objects in our test video. Let's watch our model bring our data to life!

# %% [markdown]
# This command is using the `yolo` command-line tool to perform object detection on a video file. Here's what each part of the command does:
#
# - `task=detect`: This sets the task to 'detect', which means we're going to perform object detection.
#
# - `mode=predict`: This sets the mode to 'predict', which means we're going to use a trained model to make predictions.
#
# - `model="/Users/hemant./Intel_Final/Statement 1. /runs/detect/train2/weights/best.pt"`: This specifies the path to the trained model that we're going to use for prediction.
#
# - `source="/Users/hemant./Intel_Final/Video Data/test_2.mp4"`: This specifies the path to the video file that we're going to perform object detection on.
#
# - `save=True`: This means that the output (i.e., the video with the detected objects highlighted) will be saved to disk.

# %%
# !yolo task=detect mode=predict model="/Users/hemant./Intel_Final/Statement 2. /runs/detect/train6/weights/best.pt" source="/Users/hemant./Intel_Final/Video Cutted Part/2.mp4" save=True
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.11.5 torch-2.3.0 CPU (Apple M1)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# [ WARN:0@1.636] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (2386) handleMessage OpenCV | GStreamer warning: your GStreamer installation is missing a required plugin
# [ WARN:0@1.636] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (2402) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module uridecodebin0 reported: Your GStreamer installation is missing a plug-in.
# ...

# %% [markdown]
# # 🎬 Action Time: Running Object Detection on a Video
#
# We've trained our model and it's time to put it to the test! We're going to run our YOLO model on a video, frame by frame. Watch as our model identifies and annotates objects in real-time. It's like watching magic unfold!

# %% [markdown]
# # This Python script uses the YOLO model to perform object detection on a video. Here's a brief rundown:
#
# - It starts by importing necessary modules and loading the trained YOLO model.
# - It then opens a video file for processing.
# - Inside a loop, it reads each frame of the video and feeds it to the model for prediction.
# - The model's predictions, which include bounding boxes and class labels, are then annotated on the frame using the `Annotator` class.
# - The annotated frame is converted to RGB format and displayed.
# - This process continues until all frames of the video have been processed.
# - Finally, the video file is released and a completion message is printed.

# %%
import cv2
import IPython.display as ipd
from IPython.display import clear_output
import time
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator

# Load model karenge
model = YOLO('/Users/hemant./Intel_Final/Statement 2. /runs/detect/train6/weights/best.pt')

video_path = '/Users/hemant./Intel_Final/Video Cutted Part/2.mp4'
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

display_rate = 0.5  
last_display_time = time.time()

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        results = model.predict(frame, show=True)
        detections = results[0] if isinstance(results, list) and len(results) > 0 else None

        
        annotator = Annotator(frame, line_width=2, font_size=10)

        if detections and hasattr(detections, 'boxes') and hasattr(detections.boxes, 'data'):
            box_data = detections.boxes.data
            if box_data is not None:
                for box in box_data:
                    x1, y1, x2, y2, conf, cls_id = map(int, box[:6])
                    label = detections.names.get(cls_id, 'Unknown')
                    annotator.box_label([x1, y1, x2, y2], f"{label} {conf:.2f}")

        annotated_frame = annotator.result()  

        # RGB me convert karega 
        annotated_frame = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)

        if time.time() - last_display_time > display_rate:
            ipd.display(ipd.Image(cv2.imencode('.png', annotated_frame)[1].tobytes()))
            clear_output(wait=True)
            last_display_time = time.time()

finally:
    cap.release()
    cv2.destroyAllWindows()
    print("Video processing complete.")
# Out:
# 0: 128x224 2 Movement-NOs, 1 Movement-Yes, 15.6ms
# Speed: 0.9ms preprocess, 15.6ms inference, 0.2ms postprocess per image at shape (1, 3, 128, 224)
# Video processing complete.

# %%
from ultralytics import YOLO
import os

data_path = '/Users/hemant./Intel_Final/Statement 2. /Statement 2.v1i.yolov8/data.yaml'
model_path = '/Users/hemant./Intel_Final/Statement 2. /runs/detect/train6/weights/best.pt'


model = YOLO(model_path)

results = model.val(data=data_path)


print(results)
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.11.5 torch-2.3.0 CPU (Apple M1)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /Users/hemant./Intel_Final/Statement 2. /Statement 2.v1i.yolov8/valid/labels.cache... 8 images, 0 backgrounds, 0 corrupt: 100%|██████████| 8/8 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.79it/s]
#                    all          8          8      0.895          1      0.984      0.524
#            Movement-NO          6          6      0.855          1      0.972      0.467
#           Movement-Yes          2          2      0.935          1      0.995      0.581
# Speed: 0.2ms preprocess, 40.5ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to runs/detect/val6
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# ...

# %%
from ultralytics import YOLO

data_path = '/Users/hemant./Intel_Final/Statement 2. /Statement 2.v1i.yolov8/data.yaml'
model_path = '/Users/hemant./Intel_Final/Statement 2. /runs/detect/train6/weights/best.pt'
model = YOLO(model_path)

results = model.val(data=data_path)

metrics = results.results_dict
precision = metrics['metrics/precision(B)']
recall = metrics['metrics/recall(B)']
map_50 = metrics['metrics/mAP50(B)']
map_50_95 = metrics['metrics/mAP50-95(B)']

print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"mAP@0.5: {map_50:.3f}")
print(f"mAP@0.5:0.95: {map_50_95:.3f}")

class_names = results.names

print("\nClass-wise metrics:")
for class_idx, class_name in enumerate(class_names):
    class_results = results.per_class[class_idx]
    precision = class_results['precision']
    recall = class_results['recall']
    map_50 = class_results['map_50']
    map_50_95 = class_results['map_50_95']
    
    print(f"Class: {class_name}")
    print(f" Precision: {precision:.3f}")
    print(f" Recall: {recall:.3f}")
    print(f" mAP@0.5: {map_50:.3f}")
    print(f" mAP@0.5:0.95: {map_50_95:.3f}")
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.11.5 torch-2.3.0 CPU (Apple M1)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /Users/hemant./Intel_Final/Statement 2. /Statement 2.v1i.yolov8/valid/labels.cache... 8 images, 0 backgrounds, 0 corrupt: 100%|██████████| 8/8 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.97it/s]
#                    all          8          8      0.895          1      0.984      0.524
#            Movement-NO          6          6      0.855          1      0.972      0.467
#           Movement-Yes          2          2      0.935          1      0.995      0.581
# Speed: 0.3ms preprocess, 37.7ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to runs/detect/val7
# Precision: 0.895
# Recall: 1.000
# mAP@0.5: 0.984
# mAP@0.5:0.95: 0.524
#
# Class-wise metrics:
# ...

# %%
print(dir(results))
print(results.results_dict)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'ap_class_index', 'box', 'class_result', 'confusion_matrix', 'curves', 'curves_results', 'fitness', 'keys', 'maps', 'mean_results', 'names', 'on_plot', 'plot', 'process', 'results_dict', 'save_dir', 'speed', 'task']
# {'metrics/precision(B)': 0.8950439182995845, 'metrics/recall(B)': 1.0, 'metrics/mAP50(B)': 0.9835714285714285, 'metrics/mAP50-95(B)': 0.5238245527701464, 'fitness': 0.5697992403502746}
# ...

# %% [markdown]
# # 🎉 Project Completion: A Journey Well Travelled
#
#
# ## Project 2: Patient Activity Recognition
#
# Our mission was to train a new deep learning model to identify various activities of a patient when they are alone. This wasn't just about recognizing movement; it was about understanding the patient's state and behavior in the absence of healthcare professionals or family members.
#
# Both these tools could potentially provide valuable insights into patient behavior and activity, helping healthcare professionals better understand their patients' needs and improve their care.
#
# Thank you for being a part of this incredible journey. Here's to many more!
#
# >> "In the silence of solitude, every movement tells a tale of health and healing."
